# %% [markdown]
# # Fast Transient Searches
#
# Author: Igor Andreoni <br>
# Contact: andreoni@umd.edu <br>
# ZTF Summer School 2022

# %% [markdown]
# ### Objective
# The objective of this notebook is to learn how to mine a large dataset for (rare) extragalactic fast transient sources.
#
# ### Introduction
# Wide-field surveys like the Zwicky Transient Facility (ZTF) image the entire observable sky almost every night multiple times. This makes ZTF as excellent instrument for time-domain astronomy. Image subtraction between a new "science" image and a deep "reference" (or "template") image makes every new source, or every source that changes in luminosity, stand out. When such a source is identified in a new image, an alert packet is issued, which is a dictionary rich with information, including differential photometry between the science and the template images.
#
# ZTF issues about 300,000 alerts every night. Searching for extragalactic fast transients constitutes a "needle in the haystack" big data challenge.
#
# ### Method
# A data set (see below) is provided which is very similar to the stream of alerts that ZTF issues in one night. The amount of alerts is in the order of ~100k, which is a number large enough to make it unsustainable for a human to check each source individually on a daily basis. The objective of the notebook is to apply a number of well-motivated cuts to bring an overwhelming amount of information down to a manageable number of transients that astronomers can vet. The main steps will be:
# - read and understand the data
# - plot light curves
# - apply cuts progressively
# - when < 10 candidates are left, inspect them in detail
#
#
# ### The data set
# Two data files were prepared for this school activity, both in JSON format. JSON files are, essentially, dictionaries.
#
# The alerts were all issued on the night of 2021-02-05 UT. The total number of alerts issued on that night approximated 1 million. If all the alerts were to be used, complete with all their entries, they total disk space for the 2021-02-05 night is larger than 16GB. To facilitate the download and handling of the data, alerts were selected that:
# - have at least 2 detections for the source (ndethist >= 2)
# - are likely real according to two real/bogus classifiers (drb > 0.8; braai > 0.8)
# - left a positive residual after image subtraction, i.e. the flux in the science image is larger than in the template image (warning: the source might have been fainter than the template in a past science image, generating a "negative" subtraction!)
#
# The data files are `data/fast_transient_alerts.json` for the alerts, `data/fast_transient_lc.json` for the light curves.
#
# - `data/fast_transient_alerts.json` Uniform JSON file (readable as a table using `pandas`) containing a selection of relevant information from the original alerts.
# - `data/fast_transient_lc.json` Light curves. The light curve of some transients have thousands of data points. To keep the data set manageable and our eyes on the scientific objective to discover fast transients, some the light curves were cut. In particular, **empty light curves** were assigned to those transients that:
#     - have at least one "negative" subtraction in the past (see above)
#     - are located at Galactic latitude `-8 deg < b < +8 deg` <br>
# In addition, only those data points within the last 30 days before the alert was issued are present in the light curves. Long-duration transients, variables, and repeatingly bursting sources are outside the scope of this activity. However, data points acquired after the last alert included in the `fast_transient_alerts.json` file will be present.
#
# ### Requirements
# * python 3
# * numpy, pandas, matplotlib, astropy, collections
#
# ### Useful links
# [ZTF Avro schema for the alerts](https://zwickytransientfacility.github.io/ztf-avro-alert/schema.html)<br>
# [Public ZTF alerts](https://ztf.uw.edu/alerts/public/)<br>
# [Alert brokers for ZTF and Rubin Observatory](https://www.lsst.org/scientists/alert-brokers)

# %% [markdown]
# ## Import python packages

# %%
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import OrderedDict

# %% [markdown]
# ## Read and understand the data

# %% [markdown]
# Read the data file. Beware that this action could take several minutes. The alerts JSON file is uniform and can be read as a `pandas` data frame.

# %%
# Open the file with the alerts
alerts_filename = "./data/fast_transient_alerts.json"
df_alerts = pd.read_json(alerts_filename)
# To have one alert per row instead of column, use transpose()
df_alerts = df_alerts.transpose()

# %%
df_alerts
# Out:
#                                       jd fid isdiffpos rcid          ra  \
# 601cb75947230767c903ce48  2459250.626065   1         t   45   41.706031
# 601cb758040c9a45b915243b  2459250.626065   1         t   52    46.59873
# 601cb761da8192014092f81a  2459250.626065   1         t    4    46.82753
# 601cb75284abedb0473956ad  2459250.626065   1         t   27   44.834644
# 601cb758da8192014092f80d  2459250.626065   1         t   52    46.82591
# ...                                  ...  ..       ...  ...         ...
# 601d27da84abedb04739f084  2459250.958634   1         t   24  163.434033
# 601d27ac040c9a45b915babc  2459250.958634   1         t   31  161.765062
# 601d27d3da81920140939031  2459250.958634   1         t   19  168.773193
# 601d27d1739b2bb2412ca39b  2459250.958634   1         t    7  166.154602
# 601d27ca040c9a45b915bac7  2459250.958634   1         t   14  159.981289
#
#                                 dec     magpsf  sigmapsf        rb ssdistnr  \
# 601cb75947230767c903ce48 -22.509571  15.914849  0.052548  0.512857   -999.0
# 601cb758040c9a45b915243b -20.729952  19.315357  0.187526  0.528571   -999.0
# 601cb761da8192014092f81a -27.066677  19.544296  0.215844  0.545714   -999.0
# 601cb75284abedb0473956ad -25.714721  19.561789  0.213745      0.56   -999.0
# 601cb758da8192014092f80d -20.531972  18.419357  0.183404  0.595714   -999.0
# ...                             ...        ...       ...       ...      ...
# 601d27da84abedb04739f084  43.836402  18.297316  0.069884  0.978571      0.0
# 601d27ac040c9a45b915babc  42.716231  18.129463  0.073452      0.98   -999.0
# 601d27d3da81920140939031  42.992601  18.081432  0.065831  0.984286      0.0
# 601d27d1739b2bb2412ca39b  40.622032  19.469931  0.131736  0.984286   -999.0
# 601d27ca040c9a45b915bac7  40.987857  19.727247  0.168976  0.987143   -999.0
#
#                           ...     jdstarthist       jdendhist     srmag2  \
# 601cb75947230767c903ce48  ...  2458383.932454  2459250.626065    18.7122
# 601cb758040c9a45b915243b  ...  2458860.605127  2459250.626065    21.7882
# 601cb761da8192014092f81a  ...  2459117.897257  2459250.626065    20.7647
# 601cb75284abedb0473956ad  ...  2458423.900556  2459250.626065    21.4858
# 601cb758da8192014092f80d  ...  2458427.813866  2459250.626065    20.7204
# ...                       ...             ...             ...        ...
# 601d27da84abedb04739f084  ...  2459250.958171  2459250.958634  21.620899
# 601d27ac040c9a45b915babc  ...  2458129.908634  2459250.958634    21.9601
# 601d27d3da81920140939031  ...  2459250.958171  2459250.958634     -999.0
# 601d27d1739b2bb2412ca39b  ...  2458156.827859  2459250.958634     -999.0
# 601d27ca040c9a45b915bac7  ...  2458464.983657  2459250.958634     20.958
#
#                           sgscore2  distpsnr2     srmag3  sgscore3  distpsnr3  \
# 601cb75947230767c903ce48       1.0  11.778825     -999.0       0.5   15.36731
# 601cb758040c9a45b915243b  0.906845   5.796002  21.646299  0.923917  13.633864
# 601cb761da8192014092f81a     0.005   23.80216     -999.0    -999.0     -999.0
# 601cb75284abedb0473956ad   0.00125  29.997917     -999.0    -999.0     -999.0
# 601cb758da8192014092f80d       0.5   18.06329  20.993299   0.00125  18.108027
# ...                            ...        ...        ...       ...        ...
# 601d27da84abedb04739f084       0.5   4.848219     -999.0       0.5   7.036485
# 601d27ac040c9a45b915babc  0.921958  10.335657  21.554001  0.092458  21.886131
# 601d27d3da81920140939031    -999.0     -999.0     -999.0    -999.0     -999.0
# 601d27d1739b2bb2412ca39b  0.122494  16.965469     -999.0    -999.0     -999.0
# 601d27ca040c9a45b915bac7  0.982167   8.612084    21.4468       0.0  17.771406
#
#                                drb      objectId
# 601cb75947230767c903ce48  0.975172  ZTF18abyitqr
# 601cb758040c9a45b915243b  0.999086  ZTF20aafuwfv
# 601cb761da8192014092f81a  0.988304  ZTF20acekgfz
# 601cb75284abedb0473956ad  0.998478  ZTF20acmnhcd
# 601cb758da8192014092f80d  0.992726  ZTF18abuwcid
# ...                            ...           ...
# 601d27da84abedb04739f084  0.999998  ZTF21aahffzu
# 601d27ac040c9a45b915babc  0.999999  ZTF18aaacwwr
# 601d27d3da81920140939031  0.999995  ZTF21aahffzs
# 601d27d1739b2bb2412ca39b  0.999999  ZTF18acsuill
# 601d27ca040c9a45b915bac7       1.0  ZTF20acjqfyo
#
# [106560 rows x 24 columns]

# %%
# Open the file with the light curves
lc_filename = "./data/fast_transient_lc.json"
  
# Opening JSON file
f = open(lc_filename)
  
# returns JSON object as a dictionary
lc_dict = json.load(f)

# %% [markdown]
# What do the data look like? It is a good idea to see what the data variables include, but we have to be careful about printing such a large amount of information all at once. Exploring the length of what we are going to print first is racommended.

# %% [markdown]
# Observing the first few key-value pairs for the light curve shows that each key is the name of a transient, and then it holds some observational data. The first non-empty value is:

# %%
lc_dict['ZTF17aaaoabk']
# Out:
# [{'jd': 2459221.90113, 'magpsf': 19.781, 'sigmapsf': 0.105, 'filter': 'r'},
#  {'jd': 2459223.95735, 'magpsf': 19.594, 'sigmapsf': 0.096, 'filter': 'r'},
#  {'jd': 2459230.86845, 'magpsf': 19.676, 'sigmapsf': 0.224, 'filter': 'r'},
#  {'jd': 2459230.86892, 'magpsf': 19.657, 'sigmapsf': 0.238, 'filter': 'r'},
#  {'jd': 2459231.87228, 'magpsf': 19.693, 'sigmapsf': 0.079, 'filter': 'r'},
#  {'jd': 2459231.89081, 'magpsf': 19.642, 'sigmapsf': 0.199, 'filter': 'r'},
#  {'jd': 2459249.87436, 'magpsf': 19.659, 'sigmapsf': 0.146, 'filter': 'r'},
#  {'jd': 2459250.83302, 'magpsf': 19.726, 'sigmapsf': 0.221, 'filter': 'r'},
#  {'jd': 2459250.8335, 'magpsf': 19.678, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459251.82549, 'magpsf': 19.995, 'sigmapsf': 0.143, 'filter': 'r'},
#  {'jd': 2459253.83769, 'magpsf': 19.93, 'sigmapsf': 0.106, 'filter': 'r'},
#  {'jd': 2459263.88043, 'magpsf': 19.682, 'sigmapsf': 0.145, 'filter': 'r'},
#  {'jd': 2459275.81691, 'magpsf': 19.997, 'sigmapsf': 0.184, 'filter': 'r'}]

# %%
# just the ones with data
lc_dict_data = {k:v for k, v in lc_dict.items() if len(v) > 0}

# %%
# How many alerts do we have?
len(lc_dict.keys()) # this many named events
len(lc_dict_data.keys()) # this many with observations
# Out:
# 20964

# %%
# What is the name of the alerts data frame columns?
df_alerts.columns
# Out:
# Index(['jd', 'fid', 'isdiffpos', 'rcid', 'ra', 'dec', 'magpsf', 'sigmapsf',
#        'rb', 'ssdistnr', 'srmag1', 'sgscore1', 'distpsnr1', 'ndethist',
#        'jdstarthist', 'jdendhist', 'srmag2', 'sgscore2', 'distpsnr2', 'srmag3',
#        'sgscore3', 'distpsnr3', 'drb', 'objectId'],
#       dtype='object')

# %% [markdown]
# **STOP**. What do these column names mean? In order to use them in a smart way, check them out in the [ZTF Avro schema](https://zwickytransientfacility.github.io/ztf-avro-alert/schema.html)

# %% [markdown]
# Important ones - `jd`: time of observation,

# %%
#What do alerts look like, in this short version?
df_alerts[0:3]
# Out:
#                                       jd fid isdiffpos rcid         ra  \
# 601cb75947230767c903ce48  2459250.626065   1         t   45  41.706031
# 601cb758040c9a45b915243b  2459250.626065   1         t   52   46.59873
# 601cb761da8192014092f81a  2459250.626065   1         t    4   46.82753
#
#                                 dec     magpsf  sigmapsf        rb ssdistnr  \
# 601cb75947230767c903ce48 -22.509571  15.914849  0.052548  0.512857   -999.0
# 601cb758040c9a45b915243b -20.729952  19.315357  0.187526  0.528571   -999.0
# 601cb761da8192014092f81a -27.066677  19.544296  0.215844  0.545714   -999.0
#
#                           ...     jdstarthist       jdendhist   srmag2  \
# 601cb75947230767c903ce48  ...  2458383.932454  2459250.626065  18.7122
# 601cb758040c9a45b915243b  ...  2458860.605127  2459250.626065  21.7882
# 601cb761da8192014092f81a  ...  2459117.897257  2459250.626065  20.7647
#
#                           sgscore2  distpsnr2     srmag3  sgscore3  distpsnr3  \
# 601cb75947230767c903ce48       1.0  11.778825     -999.0       0.5   15.36731
# 601cb758040c9a45b915243b  0.906845   5.796002  21.646299  0.923917  13.633864
# 601cb761da8192014092f81a     0.005   23.80216     -999.0    -999.0     -999.0
#
#                                drb      objectId
# 601cb75947230767c903ce48  0.975172  ZTF18abyitqr
# 601cb758040c9a45b915243b  0.999086  ZTF20aafuwfv
# 601cb761da8192014092f81a  0.988304  ZTF20acekgfz
#
# [3 rows x 24 columns]

# %% [markdown]
# Let's warm up with selection criteria for the alerts. For example, we can check if any one of the alerts has exactly 20 detections in its history, it is at least 5 arcsec away from the closest PS1 catalog source, and the closest PS1 cataloged source is likely a galaxy. Remember that the star/galaxy classification goes from 0 (likely galaxy) to 1 (likely star).

# %%
crit_test = (df_alerts['ndethist'] == 20) & (df_alerts['distpsnr1'] > 5) & (df_alerts['sgscore1'] < 0.5)
df_alerts[crit_test]["objectId"]
# Out:
# 601cfaac6fbae9e71c9bcabe    ZTF21aagnvvk
# 601d038d6fbae9e71c9bd805    ZTF21aagmryd
# Name: objectId, dtype: object

# %% [markdown]
# Let's display a light curve. For example, the dataset includes ZTF21aagnvvk, which is a Type Ia supernova that was assigned IAU name [AT2021bnf](https://www.wis-tns.org/object/2021bnf). You should have found this transient using the selection criteria in the cell above.
#
# To make things easier, the filter id (`fid`) column was replaced with the `filter` name (g, r, or i) column. Note that upper limits from non-detections are not included in this data set, so you will find only information about detections, even if knowing the last non-detection time of a transient can be crucial to constrain its onset.

# %%
lc_dict["ZTF21aagnvvk"]
# Out:
# [{'jd': 2459232.78481, 'magpsf': 20.856, 'sigmapsf': 0.371, 'filter': 'g'},
#  {'jd': 2459232.88103, 'magpsf': 20.705, 'sigmapsf': 0.269, 'filter': 'g'},
#  {'jd': 2459232.92484, 'magpsf': 20.591, 'sigmapsf': 0.286, 'filter': 'g'},
#  {'jd': 2459233.77119, 'magpsf': 20.487, 'sigmapsf': 0.273, 'filter': 'r'},
#  {'jd': 2459248.75645, 'magpsf': 19.06, 'sigmapsf': 0.11, 'filter': 'g'},
#  {'jd': 2459248.76622, 'magpsf': 19.032, 'sigmapsf': 0.09, 'filter': 'g'},
#  {'jd': 2459248.75551, 'magpsf': 19.082, 'sigmapsf': 0.104, 'filter': 'g'},
#  {'jd': 2459248.86705, 'magpsf': 18.948, 'sigmapsf': 0.104, 'filter': 'r'},
#  {'jd': 2459248.88325, 'magpsf': 18.924, 'sigmapsf': 0.094, 'filter': 'r'},
#  {'jd': 2459248.90036, 'magpsf': 19.016, 'sigmapsf': 0.113, 'filter': 'g'},
#  {'jd': 2459248.88231, 'magpsf': 19.025, 'sigmapsf': 0.094, 'filter': 'r'},
#  {'jd': 2459248.93757, 'magpsf': 19.023, 'sigmapsf': 0.11, 'filter': 'r'},
#  {'jd': 2459249.79897, 'magpsf': 19.158, 'sigmapsf': 0.28, 'filter': 'r'},
#  {'jd': 2459249.88734, 'magpsf': 18.997, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459250.7448, 'magpsf': 19.049, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459249.83978, 'magpsf': 19.016, 'sigmapsf': 0.151, 'filter': 'r'},
#  {'jd': 2459250.77574, 'magpsf': 19.082, 'sigmapsf': 0.121, 'filter': 'g'},
#  {'jd': 2459250.79469, 'magpsf': 19.041, 'sigmapsf': 0.125, 'filter': 'g'},
#  {'jd': 2459250.82382, 'magpsf': 19.083, 'sigmapsf': 0.116, 'filter': 'g'},
#  {'jd': 2459250.85462, 'magpsf': 18.978, 'sigmapsf': 0.124, 'filter': 'r'},
#  {'jd': 2459250.79564, 'magpsf': 19.11, 'sigmapsf': 0.117, 'filter': 'g'},
#  {'jd': 2459250.90696, 'magpsf': 19.059, 'sigmapsf': 0.147, 'filter': 'r'},
#  {'jd': 2459250.90743, 'magpsf': 19.041, 'sigmapsf': 0.127, 'filter': 'r'},
#  {'jd': 2459251.77016, 'magpsf': 19.155, 'sigmapsf': 0.108, 'filter': 'g'},
#  {'jd': 2459251.81271, 'magpsf': 19.065, 'sigmapsf': 0.105, 'filter': 'r'},
#  {'jd': 2459251.81841, 'magpsf': 19.032, 'sigmapsf': 0.102, 'filter': 'r'},
#  {'jd': 2459252.71361, 'magpsf': 18.996, 'sigmapsf': 0.137, 'filter': 'r'},
#  {'jd': 2459251.82029, 'magpsf': 19.047, 'sigmapsf': 0.107, 'filter': 'r'},
#  {'jd': 2459251.8678, 'magpsf': 19.164, 'sigmapsf': 0.109, 'filter': 'g'},
#  {'jd': 2459252.78422, 'magpsf': 19.143, 'sigmapsf': 0.102, 'filter': 'g'},
#  {'jd': 2459252.78564, 'magpsf': 19.25, 'sigmapsf': 0.123, 'filter': 'g'},
#  {'jd': 2459252.81398, 'magpsf': 19.066, 'sigmapsf': 0.119, 'filter': 'r'},
#  {'jd': 2459252.87178, 'magpsf': 18.984, 'sigmapsf': 0.1, 'filter': 'r'},
#  {'jd': 2459254.77025, 'magpsf': 19.1, 'sigmapsf': 0.1, 'filter': 'r'},
#  {'jd': 2459254.77646, 'magpsf': 19.265, 'sigmapsf': 0.095, 'filter': 'g'},
#  {'jd': 2459256.73625, 'magpsf': 19.095, 'sigmapsf': 0.095, 'filter': 'r'},
#  {'jd': 2459256.79487, 'magpsf': 19.33, 'sigmapsf': 0.105, 'filter': 'g'},
#  {'jd': 2459260.7558, 'magpsf': 19.245, 'sigmapsf': 0.192, 'filter': 'r'},
#  {'jd': 2459260.80374, 'magpsf': 19.601, 'sigmapsf': 0.159, 'filter': 'g'}]

# %% [markdown]
# ## Plot a light curve
# Define a function to plot the light curve of a given transient

# %%
def plot_lc(name):
    """
    Plot a light curve given a ZTF transient name.
    Assume lc_dict to be a global variable already defined.

    Parameters
    ----------
    name str
        name (objectId) of the ZTF transient
    """
    # Get the lc of interest
    lc = lc_dict[name]
    # What are the filters in which it was observed
    filters = [x["filter"] for x in lc]
    
    # Initialize the figure
    fig, ax = plt.subplots()
    
    # Plot the light curve in each filter
    for f in set(filters):
        time = [x["jd"] for x in lc if x['filter'] == f]
        mag = [x["magpsf"] for x in lc if x['filter'] == f]
        magerr = [x["sigmapsf"] for x in lc if x['filter'] == f]
        ax.errorbar(time, mag, yerr=magerr, marker="o", label=f)
    # Legend without repeatitions
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = OrderedDict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys())
    # Axes name
    ax.set_xlabel("time (days)")
    ax.set_ylabel("Magnitude")
    
    # Note: smaller magnitude means larger luminosity!
    ax.set_ylim(ax.get_ylim()[::-1])

# %%
# Try out the new function ZTF21aagnvvk
plot_lc("ZTF21aagnvvk")

# %% [markdown]
# Bonus quiz: Now try out the plotting function on ZTF21aagmryd. Can you guess which type of supernova this is ONLY based on the light curve?
#
# **Type II?**

# %%
plot_lc("ZTF21aagmryd")

# %% [markdown]
# # Fast transient quest
#
# Now the real search for fast transients begins!

# %% [markdown]
# ## Moving objects
#
# <img src="./figures/figure_asteroid.jpg" alt="drawing" width="500"/>
#
# Objects that move in the sky significantly in little time are likely asteroids or other types of natural (or artificial) near-Earth objects. Those must be removed from the sample.
#
# The ZTF alerts include valuable information such as the distance to the nearest catalogued solar system objects (`ssdistnr`). How many alerts fall within 10 arcsec from a catalog solar system object? Note: if no match is found, `ssdistnr == -999`

# %%
crit_moving = (df_alerts["ssdistnr"] < 10) & (df_alerts["ssdistnr"] > 0)
len(df_alerts[crit_moving])
# Out:
# 808

# %%
# Now define a criterion to EXCLUDE those moving objects
crit_nomoving = ~crit_moving
len(df_alerts[crit_nomoving])
# Out:
# 105752

# %% [markdown]
# This is good, but probably not enough to exclude all the moving objects. Some may be uncataloged, and others might not be precisely localized. Another effective way to remove moving objects is to set a minimum time gap between the first and the last detection of a transient. Usually, asteroids move > 1 arcsec every 15 minutes. Our target transients (kilonovae, GRB afterglows) evolve in minutes to days time scales, so we can afford to set a minimum time gap of 30 minutes, for extra safety.
#
# To build this criterion, we can use the `jd` and the `jdstarthist` keys present in every alert.

# %%
# jd in days: 30 minutes = 30 min / (24hr*60min per day)
crit_mingap = (df_alerts["jd"] - df_alerts["jdstarthist"] > 30/(24*60))
len(df_alerts[crit_mingap])
# Out:
# 89942

# %% [markdown]
# Putting the no-moving criteria together, what fraction of alerts remains?

# %%
len(df_alerts[crit_nomoving & crit_mingap])/len(df_alerts)
# Out:
# 0.8430930930930931

# %% [markdown]
# ## Stellarity
# “Dwell on the beauty of life. Watch the stars, and see yourself running with them.” <br>
# ― Marcus Aurelius, Meditations
#
# “Dwell on the beauty of life. Watch the stars, and see yourself running away from them.” <br>
# ― Extragalactic Astronomers
#
# <img src="./figures/figure_stellarity.png" alt="drawing" width="400"/>

# %% [markdown]
# The star/galaxy classifier can help us remove stellar sources from the sample. As mentioned before, the star/galaxy classification goes from 0 (likely galaxy) to 1 (likely star). We can wonder:
# - is the location of the transient coincident with the location of a catalogued source?
# - is the closest source likely a star or a galaxy?
#
# A combination of `sgscore1` and `distpsnr1` will answer both questions. Remember that the PSF of the ZTF camera has FWHM ~ 1 arcsec and the seeing at Palomar Observatory is often 1.0-1.5 arcsec.

# %%
crit_stellar = (df_alerts["sgscore1"] > 0.5) & (df_alerts["distpsnr1"] < 1.5) & (df_alerts["distpsnr1"] >= 0)
crit_nostellar = ~crit_stellar

# %% [markdown]
# What fraction of alerts are likely generated by stellar sources? (Imagine what this fraction would be if we included also those sources with Galactic latitude |b| < 8 deg)

# %%
len(df_alerts[crit_stellar])/len(df_alerts)
# Out:
# 0.7587743993993994

# %% [markdown]
# Bonus: plot the light curve of the star with most detections among those never brighter than 17 mag in any band.

# %%
stars = df_alerts[crit_stellar]
s = pd.DataFrame(stars.groupby(stars['objectId']).size())
s = s.sort_values(0, ascending=False)
s
# Out:
#                0
# objectId
# ZTF18aacgqfy  18
# ZTF18abvttnr  17
# ZTF18acenifl  15
# ZTF18aaacmyn  14
# ZTF19accsxdw  14
# ...           ..
# ZTF18abtzcap   1
# ZTF18abtzcut   1
# ZTF18abtzdeb   1
# ZTF18abtzdfe   1
# ZTF21aahfjzk   1
#
# [51888 rows x 1 columns]

# %%
star_dim = ''
for name in s.index:
    try: 
        lc = lc_dict_data[name]
        mag = [x["magpsf"] for x in lc if x["magpsf"]  >= 17]
        
        # all points must remain
        if len(mag) == len(lc):
            star_dim = name
            break
        
    except KeyError:
        print('')

# %%
plot_lc(star_dim)

# %% [markdown]
# ## Total duration
# We are interested in fast transients, but what this means is somewhat ambiguous. However, if we think of electromagnetic counterparts to gravitational waves, we expect them to remain bright (for a given detection limit) for a few days, perhaps weeks but only for exceptionally nearby or bright cases.
#
# Bonus quiz: assuming that ZTF has a limitng magnitude of ~20.5 mag, how long would a GW170817-like kilonova be detectable in g and r band? What if it was located at 120 Mpc instead of 41 Mpc?

# %%
# Set a threshold for the duration
max_duration = 5 # a few days - length Gw170817 < 20.5mag
crit_maxduration = (df_alerts['jdendhist'] - df_alerts['jdstarthist'] < max_duration)
len(df_alerts[crit_maxduration])
# Out:
# 17291

# %% [markdown]
# **Note:** The light curves put together for this notebook contain data points that were acquired even **after** the last alert present in the datafile. Therefore some transients pass the total duration criterion, but their light curve plot will show a long-duration transient. Building a criterion based on the light curves rather than on the alerts would yield an even better selection.

# %% [markdown]
# ## Put together the selection criteria
# How many alerts are left when the criteria for moving objects, stellarity, and duration are put together? How many transients? What is the fraction of sources that were discarded in the process?

# %%
df_alerts_select = df_alerts[crit_nomoving & crit_nostellar & crit_maxduration]
print("Number of alerts left:", len(df_alerts_select))
print("Number of transients that pass the cuts:", len(set(df_alerts_select['objectId']))) # remember objectId
# Discarded sources
n_tot_sources = len(set(df_alerts["objectId"]))
n_select_sources = len(set(df_alerts_select["objectId"]))
fraction_discarded = n_select_sources/n_tot_sources
print("Fraction of discarded sources:", fraction_discarded)
# Out:
# Number of alerts left: 16404
# Number of transients that pass the cuts: 12194
# Fraction of discarded sources: 0.1744342402654994

# %% [markdown]
# This is very good, but is it good enough? Is this sustainable for daily scanning/vetting by humans? It is doable, but we can do better.

# %% [markdown]
# ## Light curve evolution
# We still have a powerful tool that we can use: the rate at which the luminosity changes! The alerts present in the data set were all generated in one night, so we should move to the light curve data at this point.
#
# In Python it is better to stay away from `for` loops, but since we have only a few hundreds of transients left, we can afford to iterate and analyze each light curve individually.
#
# Before doing that, we must define a function that determines whether a light curve shall pass or not pass a given criterion on its evolution. To do things properly, we should consider a rising phase (typically faster) and a fading phase (typically slower) and/or fit models to the data (see, e.g., the methods used in the [ZTFReST](https://ui.adsabs.harvard.edu/abs/2021ApJ...918...63A/abstract) framework). We can build a simplified version of this algorithm.

# %%
def evaluate_lc(name, thresh=0.3):
    """
    Evaluate if a light curve evolves fast enough
    Assume lc_dict to be a global variable already defined.

    Parameters
    ----------
    name str
        name (objectId) of the ZTF transient
    thresh float
        threshold for the evolution rate (mag/day)
    
    Returns
    -------
    selected bool
        if the transient fades faster than thresh
        in at least one band, returns True, otherwise False
    """
    # Initialize the variable to return
    selected = False
    # Individual light curve
    lc = lc_dict[name]
    # Iterate on the filters
    filters = [x["filter"] for x in lc] # See the plot_lc function
    for f in set(filters):
        time = [x["jd"] for x in lc if x['filter'] == f]
        mag = [x["magpsf"] for x in lc if x['filter'] == f]
        magerr = [x["sigmapsf"] for x in lc if x['filter'] == f]
        # Condition for the rise/fade rate
        if len(time) <= 2:
            selected = False
            break
        if np.abs(np.max(mag) - np.min(mag))/(time[np.argmax(mag)]-time[np.argmin(mag)]) > thresh:
            selected = True
            # No need to keep going if selected becomes True
            #break

    
    return selected

# %% [markdown]
# Let's try it out. How many transients have a light curve that evolves faster than 0.5 mag/day?

# %%
names_selected = []
for name in set(df_alerts_select["objectId"]):
    try:
        if evaluate_lc(name, 0.5) is True:
            names_selected.append(name)
    except KeyError:
        print(f"{name} not present in light curve file, ignore")
print("Number of sources to vet:", len(names_selected))
# Out:
# ZTF21aahbhna not present in light curve file, ignore
# ZTF21aahcjow not present in light curve file, ignore
# ZTF21aahdvgu not present in light curve file, ignore
# ZTF21aahbfgm not present in light curve file, ignore
# ZTF21aahcyfv not present in light curve file, ignore
# ZTF21aahbhhm not present in light curve file, ignore
# ZTF21aahbota not present in light curve file, ignore
# ZTF21aahcxbb not present in light curve file, ignore
# ZTF21aahcwtg not present in light curve file, ignore
# ZTF21aahcint not present in light curve file, ignore
# ZTF21aahdpbc not present in light curve file, ignore
# ZTF21aahdkwu not present in light curve file, ignore
# ZTF21aahbhhc not present in light curve file, ignore
# ZTF21aahcyaq not present in light curve file, ignore
# ZTF21aahbqbg not present in light curve file, ignore
# ZTF21aagzsmm not present in light curve file, ignore
# ZTF21aahbgnb not present in light curve file, ignore
# ZTF21aahapuw not present in light curve file, ignore
# ZTF21aahdohu not present in light curve file, ignore
# ZTF21aahcgcp not present in light curve file, ignore
# ZTF21aahbyly not present in light curve file, ignore
# ZTF21aahbhcj not present in light curve file, ignore
# ZTF21aahaduw not present in light curve file, ignore
# ZTF21aahdpcz not present in light curve file, ignore
# ZTF21aahbfiu not present in light curve file, ignore
# ZTF21aahbhvs not present in light curve file, ignore
# ZTF21aahbicg not present in light curve file, ignore
# ZTF21aahczov not present in light curve file, ignore
# ZTF21aahbjnb not present in light curve file, ignore
# ZTF21aahbgtm not present in light curve file, ignore
# ZTF21aahbhnx not present in light curve file, ignore
# ZTF21aahenqe not present in light curve file, ignore
# ZTF21aahbpfz not present in light curve file, ignore
# ZTF21aahbfip not present in light curve file, ignore
# ZTF21aahbiio not present in light curve file, ignore
# ZTF21aahcjsk not present in light curve file, ignore
# ZTF21aahbfdu not present in light curve file, ignore
# ZTF21aahchwe not present in light curve file, ignore
# ZTF21aahcijy not present in light curve file, ignore
# ZTF21aahcpus not present in light curve file, ignore
# ZTF21aahfdpb not present in light curve file, ignore
# ZTF21aahdvgf not present in light curve file, ignore
# ZTF21aahdvii not present in light curve file, ignore
# ZTF21aahbgzv not present in light curve file, ignore
# ZTF21aahccgw not present in light curve file, ignore
# ZTF21aahchnx not present in light curve file, ignore
# ZTF21aahbqrg not present in light curve file, ignore
# ZTF21aahcybt not present in light curve file, ignore
# ZTF21aahcyde not present in light curve file, ignore
# ZTF21aahczti not present in light curve file, ignore
# ZTF21aahcirb not present in light curve file, ignore
# ZTF21aahbhiq not present in light curve file, ignore
# ZTF21aahbntj not present in light curve file, ignore
# ZTF21aahbfnn not present in light curve file, ignore
# ZTF21aaheony not present in light curve file, ignore
# ZTF21aahbeuz not present in light curve file, ignore
# ZTF21aahcixl not present in light curve file, ignore
# ZTF21aahcikn not present in light curve file, ignore
# ZTF21aahbfzz not present in light curve file, ignore
# ZTF21aahboxf not present in light curve file, ignore
# ZTF21aahbfoa not present in light curve file, ignore
# ZTF21aahcifh not present in light curve file, ignore
# ZTF21aahdvjf not present in light curve file, ignore
# ZTF21aahbfbl not present in light curve file, ignore
# ZTF21aahchhp not present in light curve file, ignore
# ZTF21aahbgpp not present in light curve file, ignore
# ZTF21aahbfiq not present in light curve file, ignore
# ZTF21aahdxno not present in light curve file, ignore
# ZTF21aahbpgo not present in light curve file, ignore
# ZTF21aahbpyn not present in light curve file, ignore
# ZTF21aahbfpu not present in light curve file, ignore
# ZTF21aahchct not present in light curve file, ignore
# ZTF21aahfdwc not present in light curve file, ignore
# ZTF21aagzspk not present in light curve file, ignore
# ZTF21aahcylx not present in light curve file, ignore
# ZTF21aahboen not present in light curve file, ignore
# ZTF21aahbniz not present in light curve file, ignore
# ZTF21aahbogk not present in light curve file, ignore
# ZTF21aahbscy not present in light curve file, ignore
# ZTF21aahcezw not present in light curve file, ignore
# ZTF21aahbihw not present in light curve file, ignore
# ZTF21aahcgwd not present in light curve file, ignore
# ZTF21aahcigp not present in light curve file, ignore
# ZTF21aahchqy not present in light curve file, ignore
# ZTF21aaherig not present in light curve file, ignore
# ZTF21aahczsd not present in light curve file, ignore
# ZTF21aahbnja not present in light curve file, ignore
# ZTF21aahfcva not present in light curve file, ignore
# ZTF21aahajlj not present in light curve file, ignore
# ZTF21aahcxyx not present in light curve file, ignore
# ZTF21aahchqs not present in light curve file, ignore
# ZTF21aahbgdr not present in light curve file, ignore
# ZTF21aahbnrw not present in light curve file, ignore
# ZTF21aahffha not present in light curve file, ignore
# ZTF21aahbokh not present in light curve file, ignore
# ZTF21aaheewa not present in light curve file, ignore
# ZTF21aahbocq not present in light curve file, ignore
# ZTF21aahbiuc not present in light curve file, ignore
# ZTF21aahdaaq not present in light curve file, ignore
# ZTF21aahdjvn not present in light curve file, ignore
# ZTF21aaheond not present in light curve file, ignore
# ZTF21aahbkxi not present in light curve file, ignore
# ZTF21aagzipx not present in light curve file, ignore
# ZTF21aahbqcu not present in light curve file, ignore
# ZTF21aahdvle not present in light curve file, ignore
# ZTF21aahfdlz not present in light curve file, ignore
# ZTF21aahchnt not present in light curve file, ignore
# ZTF21aagzssd not present in light curve file, ignore
# ZTF21aahbfsa not present in light curve file, ignore
# ZTF21aahbqpg not present in light curve file, ignore
# ZTF21aahecms not present in light curve file, ignore
# ZTF21aagzsio not present in light curve file, ignore
# ZTF21aahcbwk not present in light curve file, ignore
# ZTF21aahcyar not present in light curve file, ignore
# ZTF21aahcjaw not present in light curve file, ignore
# ZTF21aahbexx not present in light curve file, ignore
# ZTF21aahbrpl not present in light curve file, ignore
# ZTF21aahcfvn not present in light curve file, ignore
# ZTF21aahbffs not present in light curve file, ignore
# ZTF21aahbnsy not present in light curve file, ignore
# ZTF21aahdndj not present in light curve file, ignore
# ZTF21aahbgzy not present in light curve file, ignore
# ZTF21aahcxlx not present in light curve file, ignore
# ZTF21aaheavz not present in light curve file, ignore
# ZTF21aahbgow not present in light curve file, ignore
# ZTF21aahcyas not present in light curve file, ignore
# ZTF21aahbevw not present in light curve file, ignore
# ZTF21aahczqe not present in light curve file, ignore
# ZTF21aahdvhq not present in light curve file, ignore
# ZTF21aahbnqx not present in light curve file, ignore
# ZTF21aahdlta not present in light curve file, ignore
# ZTF21aahbhge not present in light curve file, ignore
# ZTF21aagzsoi not present in light curve file, ignore
# ZTF21aahcxzx not present in light curve file, ignore
# ZTF21aahdlek not present in light curve file, ignore
# ZTF21aahdawz not present in light curve file, ignore
# ZTF21aahchzj not present in light curve file, ignore
# ZTF21aahbgzu not present in light curve file, ignore
# ZTF21aahbfth not present in light curve file, ignore
# ZTF21aahfdew not present in light curve file, ignore
# ZTF21aahcaee not present in light curve file, ignore
# ZTF21aahcioc not present in light curve file, ignore
# ZTF21aahcifm not present in light curve file, ignore
# ZTF21aahdndm not present in light curve file, ignore
# ZTF21aahcxxl not present in light curve file, ignore
# ZTF21aahdogb not present in light curve file, ignore
# ZTF21aahbbxz not present in light curve file, ignore
# ZTF21aahenqf not present in light curve file, ignore
# ZTF21aahfcst not present in light curve file, ignore
# ZTF21aahbpkx not present in light curve file, ignore
# ZTF21aahbpvr not present in light curve file, ignore
# ZTF21aahcinu not present in light curve file, ignore
# ZTF21aahcxly not present in light curve file, ignore
# ZTF21aahbhoq not present in light curve file, ignore
# ZTF21aagzspz not present in light curve file, ignore
# ZTF21aahcimd not present in light curve file, ignore
# ZTF21aahcxun not present in light curve file, ignore
# ZTF21aahbfdd not present in light curve file, ignore
# ZTF21aahccix not present in light curve file, ignore
# ZTF21aahbptg not present in light curve file, ignore
# ZTF21aahbeqy not present in light curve file, ignore
# ZTF21aahdafs not present in light curve file, ignore
# ZTF21aahcinz not present in light curve file, ignore
# ZTF21aahbihs not present in light curve file, ignore
# ZTF21aahbezb not present in light curve file, ignore
# ZTF21aahdlel not present in light curve file, ignore
# ZTF21aahdvgc not present in light curve file, ignore
# ZTF21aahbeie not present in light curve file, ignore
# ZTF21aahffte not present in light curve file, ignore
# ZTF21aahcixd not present in light curve file, ignore
# ZTF21aaheqhn not present in light curve file, ignore
# ZTF21aahdabh not present in light curve file, ignore
# ZTF21aahdaqo not present in light curve file, ignore
# ZTF21aahbpdi not present in light curve file, ignore
# ZTF21aahbhle not present in light curve file, ignore
# ZTF21aahczxt not present in light curve file, ignore
# ZTF21aaherns not present in light curve file, ignore
# ZTF21aahbtyt not present in light curve file, ignore
# ZTF21aahbdtn not present in light curve file, ignore
# ZTF21aahbfgg not present in light curve file, ignore
# ZTF21aahbgyv not present in light curve file, ignore
# ZTF21aahbeys not present in light curve file, ignore
# ZTF21aahbqpp not present in light curve file, ignore
# ZTF21aahciye not present in light curve file, ignore
# ZTF21aahcqif not present in light curve file, ignore
# ZTF21aahbqtp not present in light curve file, ignore
# ZTF21aahbebf not present in light curve file, ignore
# ZTF21aahcyrb not present in light curve file, ignore
# ZTF21aahebdp not present in light curve file, ignore
# ZTF21aahcjlw not present in light curve file, ignore
# ZTF21aahernz not present in light curve file, ignore
# ZTF21aahbhjm not present in light curve file, ignore
# ZTF21aahfcps not present in light curve file, ignore
# ZTF21aahczrs not present in light curve file, ignore
# ZTF21aahbhnw not present in light curve file, ignore
# ZTF21aahewra not present in light curve file, ignore
# ZTF21aahbuev not present in light curve file, ignore
# ZTF21aahadok not present in light curve file, ignore
# ZTF21aahamzj not present in light curve file, ignore
# ZTF21aahczyb not present in light curve file, ignore
# ZTF21aahdzal not present in light curve file, ignore
# ZTF21aahcxlt not present in light curve file, ignore
# ZTF21aahdokq not present in light curve file, ignore
# ZTF21aahbgwi not present in light curve file, ignore
# ZTF21aahcjet not present in light curve file, ignore
# ZTF21aahbicd not present in light curve file, ignore
# ZTF21aahbnmm not present in light curve file, ignore
# ZTF21aahdvfu not present in light curve file, ignore
# ZTF21aahbpql not present in light curve file, ignore
# ZTF21aahbhlt not present in light curve file, ignore
# ZTF21aahcisj not present in light curve file, ignore
# ZTF21aahchgn not present in light curve file, ignore
# ZTF21aahbhky not present in light curve file, ignore
# ZTF21aahepai not present in light curve file, ignore
# ZTF21aahcjay not present in light curve file, ignore
# ZTF21aahcjds not present in light curve file, ignore
# ZTF21aahbnzf not present in light curve file, ignore
# ZTF21aahccgq not present in light curve file, ignore
# ZTF21aahbzqt not present in light curve file, ignore
# ZTF21aahbfdb not present in light curve file, ignore
# ZTF21aahcitr not present in light curve file, ignore
# ZTF21aahdvfh not present in light curve file, ignore
# ZTF21aahbhot not present in light curve file, ignore
# ZTF21aahbczo not present in light curve file, ignore
# ZTF21aahchyh not present in light curve file, ignore
# ZTF21aahbgxq not present in light curve file, ignore
# ZTF21aahbnnp not present in light curve file, ignore
# ZTF21aahdlil not present in light curve file, ignore
# ZTF21aahdniw not present in light curve file, ignore
# ZTF21aahbpxl not present in light curve file, ignore
# ZTF21aahbrss not present in light curve file, ignore
# ZTF21aahcyhb not present in light curve file, ignore
# ZTF21aaheorv not present in light curve file, ignore
# ZTF21aahcjca not present in light curve file, ignore
# ZTF21aahbegl not present in light curve file, ignore
# ZTF21aahcxxg not present in light curve file, ignore
# ZTF21aagzslv not present in light curve file, ignore
# ZTF21aagzsld not present in light curve file, ignore
# ZTF21aahenqg not present in light curve file, ignore
# ZTF21aahdvdq not present in light curve file, ignore
# ZTF21aahbpaf not present in light curve file, ignore
# ZTF21aahbtwl not present in light curve file, ignore
# ZTF21aahbgiz not present in light curve file, ignore
# ZTF21aahfbyr not present in light curve file, ignore
# ZTF21aahdltf not present in light curve file, ignore
# ZTF21aahbnvq not present in light curve file, ignore
# ZTF21aahcwqx not present in light curve file, ignore
# ZTF21aahbgpj not present in light curve file, ignore
# ZTF21aahbiom not present in light curve file, ignore
# ZTF21aahbtyz not present in light curve file, ignore
# ZTF21aahbnqv not present in light curve file, ignore
# ZTF21aahcjde not present in light curve file, ignore
# ZTF21aahbgwz not present in light curve file, ignore
# ZTF21aahbfnz not present in light curve file, ignore
# ZTF21aahbfku not present in light curve file, ignore
# ZTF21aahbtfg not present in light curve file, ignore
# ZTF21aaheqtx not present in light curve file, ignore
# ZTF21aahchlp not present in light curve file, ignore
# ZTF21aahboas not present in light curve file, ignore
# ZTF21aahchvq not present in light curve file, ignore
# ZTF21aahdvhu not present in light curve file, ignore
# ZTF21aahbdih not present in light curve file, ignore
# ZTF21aahbnvh not present in light curve file, ignore
# ZTF21aahcxmj not present in light curve file, ignore
# ZTF21aahbiiu not present in light curve file, ignore
# ZTF21aahbhee not present in light curve file, ignore
# ZTF21aahcxul not present in light curve file, ignore
# ZTF21aahcygz not present in light curve file, ignore
# ZTF21aahbhqe not present in light curve file, ignore
# ZTF21aahbume not present in light curve file, ignore
# ZTF21aahcjak not present in light curve file, ignore
# ZTF21aahbihv not present in light curve file, ignore
# ZTF21aahbnle not present in light curve file, ignore
# ZTF21aahbgau not present in light curve file, ignore
# ZTF21aahcylr not present in light curve file, ignore
# ZTF21aahdohy not present in light curve file, ignore
# ZTF21aahdajc not present in light curve file, ignore
# ZTF21aahclla not present in light curve file, ignore
# ZTF21aahbgfh not present in light curve file, ignore
# ZTF21aahbuba not present in light curve file, ignore
# ZTF21aagzskk not present in light curve file, ignore
# ZTF21aahbulc not present in light curve file, ignore
# ZTF21aahbpdl not present in light curve file, ignore
# ZTF21aahdvkn not present in light curve file, ignore
# ZTF21aahcisi not present in light curve file, ignore
# ZTF21aahadpa not present in light curve file, ignore
# ZTF21aahdabe not present in light curve file, ignore
# ZTF21aahcjbi not present in light curve file, ignore
# ZTF21aahbpgl not present in light curve file, ignore
# ZTF21aahbozi not present in light curve file, ignore
# ZTF21aahcjgv not present in light curve file, ignore
# ZTF21aahbnyk not present in light curve file, ignore
# ZTF21aahbgvf not present in light curve file, ignore
# ZTF21aahdlaj not present in light curve file, ignore
# ZTF21aahdlcc not present in light curve file, ignore
# ZTF21aahbpvw not present in light curve file, ignore
# ZTF21aahbqai not present in light curve file, ignore
# ZTF21aahcjox not present in light curve file, ignore
# ZTF21aahcxse not present in light curve file, ignore
# ZTF21aahckpt not present in light curve file, ignore
# ZTF21aahbqtu not present in light curve file, ignore
# ZTF21aahcciw not present in light curve file, ignore
# ZTF21aahdvlm not present in light curve file, ignore
# ZTF21aahbttp not present in light curve file, ignore
# ZTF21aahbfay not present in light curve file, ignore
# ZTF21aahfdmi not present in light curve file, ignore
# ZTF21aahbimp not present in light curve file, ignore
# ZTF21aahbeep not present in light curve file, ignore
# ZTF21aahbhcu not present in light curve file, ignore
# ZTF21aahbcfs not present in light curve file, ignore
# ZTF21aahbqax not present in light curve file, ignore
# ZTF21aahadtn not present in light curve file, ignore
# ZTF21aahbdxd not present in light curve file, ignore
# ZTF21aahdaiy not present in light curve file, ignore
# ZTF21aahadpv not present in light curve file, ignore
# ZTF21aahcjog not present in light curve file, ignore
# ZTF21aahccgs not present in light curve file, ignore
# ZTF21aahbptk not present in light curve file, ignore
# ZTF21aahdfna not present in light curve file, ignore
# ZTF21aahdvgr not present in light curve file, ignore
# ZTF21aahberc not present in light curve file, ignore
# ZTF21aahbfnx not present in light curve file, ignore
# ZTF21aahbgpv not present in light curve file, ignore
# ZTF21aagzqrx not present in light curve file, ignore
# ZTF21aaheptb not present in light curve file, ignore
# ZTF21aahcxzp not present in light curve file, ignore
# ZTF21aahcxhd not present in light curve file, ignore
# ZTF21aahdlsy not present in light curve file, ignore
# ZTF21aahbzql not present in light curve file, ignore
# ZTF21aahchto not present in light curve file, ignore
# ZTF21aahbzqx not present in light curve file, ignore
# ZTF21aahcinv not present in light curve file, ignore
# ZTF21aahbogx not present in light curve file, ignore
# ZTF21aahepev not present in light curve file, ignore
# ZTF21aahcigy not present in light curve file, ignore
# ZTF21aahbfba not present in light curve file, ignore
# ZTF21aahboru not present in light curve file, ignore
# ZTF21aahczpe not present in light curve file, ignore
# ZTF21aahenqb not present in light curve file, ignore
# ZTF21aahdaja not present in light curve file, ignore
# ZTF21aahbhej not present in light curve file, ignore
# ZTF21aahcguo not present in light curve file, ignore
# ZTF21aahbpsp not present in light curve file, ignore
# ZTF21aahbnqf not present in light curve file, ignore
# ZTF21aagzsib not present in light curve file, ignore
# ZTF21aahbqev not present in light curve file, ignore
# ZTF21aahdzbm not present in light curve file, ignore
# ZTF21aahcitp not present in light curve file, ignore
# ZTF21aahcxmh not present in light curve file, ignore
# ZTF21aahddek not present in light curve file, ignore
# ZTF21aahbiiw not present in light curve file, ignore
# ZTF21aahbfyt not present in light curve file, ignore
# ZTF21aahepli not present in light curve file, ignore
# ZTF21aahenyq not present in light curve file, ignore
# ZTF21aagzslu not present in light curve file, ignore
# ZTF21aahbevb not present in light curve file, ignore
# ZTF21aahcmme not present in light curve file, ignore
# ZTF21aahcijk not present in light curve file, ignore
# ZTF21aahbnla not present in light curve file, ignore
# ZTF21aahdlet not present in light curve file, ignore
# ZTF21aahchdv not present in light curve file, ignore
# ZTF21aahcgqx not present in light curve file, ignore
# ZTF21aagzuye not present in light curve file, ignore
# ZTF21aahdvfs not present in light curve file, ignore
# ZTF21aagzsky not present in light curve file, ignore
# ZTF21aahbgdp not present in light curve file, ignore
# ZTF21aahenfm not present in light curve file, ignore
# ZTF21aahdvev not present in light curve file, ignore
# ZTF21aahchtg not present in light curve file, ignore
# ZTF21aahbnkk not present in light curve file, ignore
# ZTF21aahboaq not present in light curve file, ignore
# ZTF21aahadug not present in light curve file, ignore
# ZTF21aahciwm not present in light curve file, ignore
# ZTF21aahbioo not present in light curve file, ignore
# ZTF21aahbnnw not present in light curve file, ignore
# ZTF21aahcgku not present in light curve file, ignore
# ZTF21aahbdwc not present in light curve file, ignore
# ZTF21aahbrmd not present in light curve file, ignore
# ZTF21aahcian not present in light curve file, ignore
# ZTF21aahbqiz not present in light curve file, ignore
# ZTF21aahcjdb not present in light curve file, ignore
# ZTF21aahcjoh not present in light curve file, ignore
# ZTF21aahbfpl not present in light curve file, ignore
# ZTF21aahcyia not present in light curve file, ignore
# ZTF21aahbhav not present in light curve file, ignore
# ZTF21aahcfxd not present in light curve file, ignore
# ZTF21aahbitj not present in light curve file, ignore
# ZTF21aahbioi not present in light curve file, ignore
# ZTF21aahenzf not present in light curve file, ignore
# ZTF21aahbpwf not present in light curve file, ignore
# ZTF21aahdaae not present in light curve file, ignore
# ZTF21aahbqpm not present in light curve file, ignore
# ZTF21aahamvb not present in light curve file, ignore
# ZTF21aahbppm not present in light curve file, ignore
# ZTF21aahboxl not present in light curve file, ignore
# ZTF21aahacfm not present in light curve file, ignore
# ZTF21aahcjlq not present in light curve file, ignore
# ZTF21aahbuah not present in light curve file, ignore
# ZTF21aahcgun not present in light curve file, ignore
# ZTF21aahcibx not present in light curve file, ignore
# ZTF21aahcgey not present in light curve file, ignore
# ZTF21aahbhno not present in light curve file, ignore
# ZTF21aahczxz not present in light curve file, ignore
# ZTF21aahdajg not present in light curve file, ignore
# ZTF21aagzsih not present in light curve file, ignore
# ZTF21aahcino not present in light curve file, ignore
# ZTF21aahbpvv not present in light curve file, ignore
# ZTF21aahereo not present in light curve file, ignore
# ZTF21aahbgxh not present in light curve file, ignore
# ZTF21aahcjiu not present in light curve file, ignore
# ZTF21aahbcjh not present in light curve file, ignore
# ZTF21aahcxrx not present in light curve file, ignore
# ZTF21aahcjgx not present in light curve file, ignore
# ZTF21aahbgok not present in light curve file, ignore
# ZTF21aahbxok not present in light curve file, ignore
# ZTF21aaheeof not present in light curve file, ignore
# ZTF21aahcigm not present in light curve file, ignore
# ZTF21aahdldr not present in light curve file, ignore
# ZTF21aahbokz not present in light curve file, ignore
# ZTF21aahbeup not present in light curve file, ignore
# ZTF21aahdafd not present in light curve file, ignore
# ZTF21aahbdht not present in light curve file, ignore
# ZTF21aahbtvd not present in light curve file, ignore
# ZTF21aahcyjt not present in light curve file, ignore
# ZTF21aahcjpa not present in light curve file, ignore
# ZTF21aahbhij not present in light curve file, ignore
# ZTF21aahcitl not present in light curve file, ignore
# ZTF21aahbhtf not present in light curve file, ignore
# ZTF21aahdlqv not present in light curve file, ignore
# ZTF21aahbylz not present in light curve file, ignore
# ZTF21aahbgha not present in light curve file, ignore
# ZTF21aahempt not present in light curve file, ignore
# ZTF21aaheonq not present in light curve file, ignore
# ZTF21aahbena not present in light curve file, ignore
# ZTF21aahcoab not present in light curve file, ignore
# ZTF21aahboee not present in light curve file, ignore
# ZTF21aahbgzw not present in light curve file, ignore
# ZTF21aahbqni not present in light curve file, ignore
# ZTF21aahcxnc not present in light curve file, ignore
# ZTF21aagzsmg not present in light curve file, ignore
# ZTF21aahcgjl not present in light curve file, ignore
# ZTF21aahbzzg not present in light curve file, ignore
# ZTF21aahcila not present in light curve file, ignore
# ZTF21aahbeyo not present in light curve file, ignore
# ZTF21aahbqbw not present in light curve file, ignore
# ZTF21aahcidg not present in light curve file, ignore
# ZTF21aahbfrz not present in light curve file, ignore
# ZTF21aahchno not present in light curve file, ignore
# ZTF21aahbgna not present in light curve file, ignore
# ZTF21aahclxu not present in light curve file, ignore
# ZTF21aahbgba not present in light curve file, ignore
# ZTF21aahchgm not present in light curve file, ignore
# ZTF21aahbhsj not present in light curve file, ignore
# ZTF21aahdndd not present in light curve file, ignore
# ZTF21aahdnde not present in light curve file, ignore
# ZTF21aahdaaf not present in light curve file, ignore
# ZTF21aahcjdg not present in light curve file, ignore
# ZTF21aahbqiw not present in light curve file, ignore
# ZTF21aahcjcu not present in light curve file, ignore
# ZTF21aahbfoc not present in light curve file, ignore
# ZTF21aahchue not present in light curve file, ignore
# ZTF21aahbnqq not present in light curve file, ignore
# ZTF21aahcysk not present in light curve file, ignore
# ZTF21aahcxmw not present in light curve file, ignore
# ZTF21aahbfbs not present in light curve file, ignore
# ZTF21aahcldg not present in light curve file, ignore
# ZTF21aahcifi not present in light curve file, ignore
# ZTF21aaheehw not present in light curve file, ignore
# ZTF21aahdaou not present in light curve file, ignore
# ZTF21aahbgfe not present in light curve file, ignore
# ZTF21aahfdym not present in light curve file, ignore
# ZTF21aahbdyv not present in light curve file, ignore
# ZTF21aahergy not present in light curve file, ignore
# ZTF21aahcjwm not present in light curve file, ignore
# ZTF21aahdawg not present in light curve file, ignore
# ZTF21aahdade not present in light curve file, ignore
# ZTF21aahcjbd not present in light curve file, ignore
# ZTF21aahbudz not present in light curve file, ignore
# ZTF21aahbezj not present in light curve file, ignore
# ZTF21aahcxxc not present in light curve file, ignore
# ZTF21aaheehx not present in light curve file, ignore
# ZTF21aahdadw not present in light curve file, ignore
# ZTF21aahbhlb not present in light curve file, ignore
# ZTF21aagzshy not present in light curve file, ignore
# ZTF21aahchqx not present in light curve file, ignore
# ZTF21aahcfet not present in light curve file, ignore
# ZTF21aahczxs not present in light curve file, ignore
# ZTF21aahbgoy not present in light curve file, ignore
# ZTF21aahfcxx not present in light curve file, ignore
# ZTF21aahczot not present in light curve file, ignore
# ZTF21aahbird not present in light curve file, ignore
# ZTF21aahbgdn not present in light curve file, ignore
# ZTF21aahfdwm not present in light curve file, ignore
# ZTF21aahciou not present in light curve file, ignore
# ZTF21aahbgkx not present in light curve file, ignore
# ZTF21aahdauz not present in light curve file, ignore
# ZTF21aahdvhj not present in light curve file, ignore
# ZTF21aahcgbg not present in light curve file, ignore
# ZTF21aahcgbi not present in light curve file, ignore
# ZTF21aahbebc not present in light curve file, ignore
# ZTF21aagzxtx not present in light curve file, ignore
# ZTF21aagzsin not present in light curve file, ignore
# ZTF21aaheqhf not present in light curve file, ignore
# ZTF21aahcxmu not present in light curve file, ignore
# ZTF21aahcjoy not present in light curve file, ignore
# ZTF21aahcxzt not present in light curve file, ignore
# ZTF21aahbhbg not present in light curve file, ignore
# ZTF21aahchyt not present in light curve file, ignore
# ZTF21aahbqdz not present in light curve file, ignore
# ZTF21aahbfnb not present in light curve file, ignore
# ZTF21aahcifp not present in light curve file, ignore
# ZTF21aahdxnj not present in light curve file, ignore
# ZTF21aahbfft not present in light curve file, ignore
# ZTF21aahbntz not present in light curve file, ignore
# ZTF21aahcxfs not present in light curve file, ignore
# ZTF21aahcjkv not present in light curve file, ignore
# ZTF21aagzsiq not present in light curve file, ignore
# ZTF21aahcbfc not present in light curve file, ignore
# ZTF21aahbcfw not present in light curve file, ignore
# ZTF21aahdaro not present in light curve file, ignore
# ZTF21aahcxmf not present in light curve file, ignore
# ZTF21aahckmn not present in light curve file, ignore
# ZTF21aahcjkt not present in light curve file, ignore
# ZTF21aahbqen not present in light curve file, ignore
# ZTF21aahcifz not present in light curve file, ignore
# ZTF21aahcxaz not present in light curve file, ignore
# ZTF21aahbnvm not present in light curve file, ignore
# ZTF21aahdarn not present in light curve file, ignore
# ZTF21aahdndl not present in light curve file, ignore
# ZTF21aahcyat not present in light curve file, ignore
# ZTF21aahchyu not present in light curve file, ignore
# ZTF21aaherex not present in light curve file, ignore
# ZTF21aahckaw not present in light curve file, ignore
# ZTF21aaheqsp not present in light curve file, ignore
# ZTF21aahfcvc not present in light curve file, ignore
# ZTF21aahcimh not present in light curve file, ignore
# ZTF21aaheqhd not present in light curve file, ignore
# ZTF21aahbhal not present in light curve file, ignore
# ZTF21aahbfwj not present in light curve file, ignore
# ZTF21aahdvkz not present in light curve file, ignore
# ZTF21aahcjls not present in light curve file, ignore
# ZTF21aahbtzo not present in light curve file, ignore
# ZTF21aahfbse not present in light curve file, ignore
# ZTF21aahbofg not present in light curve file, ignore
# ZTF21aahbgas not present in light curve file, ignore
# ZTF21aahcybu not present in light curve file, ignore
# ZTF21aahbnir not present in light curve file, ignore
# ZTF21aahdkwk not present in light curve file, ignore
# ZTF21aahbfgk not present in light curve file, ignore
# ZTF21aahdvfx not present in light curve file, ignore
# ZTF21aahbgjg not present in light curve file, ignore
# ZTF21aahbhit not present in light curve file, ignore
# ZTF21aahboco not present in light curve file, ignore
# ZTF21aahbhet not present in light curve file, ignore
# ZTF21aahcxif not present in light curve file, ignore
# ZTF21aahfdyf not present in light curve file, ignore
# ZTF21aahbdpw not present in light curve file, ignore
# ZTF21aahboyf not present in light curve file, ignore
# ZTF21aahfdjz not present in light curve file, ignore
# ZTF21aahfdye not present in light curve file, ignore
# ZTF21aahergw not present in light curve file, ignore
# ZTF21aahciow not present in light curve file, ignore
# ZTF21aahchvo not present in light curve file, ignore
# ZTF21aahbogf not present in light curve file, ignore
# ZTF21aahbhop not present in light curve file, ignore
# ZTF21aahbupd not present in light curve file, ignore
# ZTF21aahcimj not present in light curve file, ignore
# ZTF21aahbukk not present in light curve file, ignore
# ZTF21aahbnyl not present in light curve file, ignore
# ZTF21aahbnlv not present in light curve file, ignore
# ZTF21aahcxoq not present in light curve file, ignore
# ZTF21aahbqpn not present in light curve file, ignore
# ZTF21aahboym not present in light curve file, ignore
# ZTF21aahbnsg not present in light curve file, ignore
# ZTF21aahbnsb not present in light curve file, ignore
# ZTF21aahdvjz not present in light curve file, ignore
# ZTF21aahbrgu not present in light curve file, ignore
# ZTF21aahbice not present in light curve file, ignore
# ZTF21aahbqhb not present in light curve file, ignore
# ZTF21aagzskq not present in light curve file, ignore
# ZTF21aahfcik not present in light curve file, ignore
# ZTF21aahdkke not present in light curve file, ignore
# ZTF21aahdvgo not present in light curve file, ignore
# ZTF21aahcicp not present in light curve file, ignore
# ZTF21aahanhx not present in light curve file, ignore
# ZTF21aahcyjq not present in light curve file, ignore
# ZTF21aahbmrk not present in light curve file, ignore
# ZTF21aagzsoa not present in light curve file, ignore
# ZTF21aagzsjp not present in light curve file, ignore
# ZTF21aahdoyt not present in light curve file, ignore
# ZTF21aahdvgb not present in light curve file, ignore
# ZTF21aahbhqx not present in light curve file, ignore
# ZTF21aahdqwj not present in light curve file, ignore
# ZTF21aahfbnj not present in light curve file, ignore
# ZTF21aahbfln not present in light curve file, ignore
# ZTF21aahbevv not present in light curve file, ignore
# ZTF21aahcqkd not present in light curve file, ignore
# ZTF21aahbine not present in light curve file, ignore
# ZTF21aahbkex not present in light curve file, ignore
# ZTF21aahcldh not present in light curve file, ignore
# ZTF21aahdldp not present in light curve file, ignore
# ZTF21aahczse not present in light curve file, ignore
# ZTF21aahbgzl not present in light curve file, ignore
# ZTF21aahbgwh not present in light curve file, ignore
# ZTF21aahdlij not present in light curve file, ignore
# ZTF21aahczrp not present in light curve file, ignore
# ZTF21aahbfwd not present in light curve file, ignore
# ZTF21aahenuf not present in light curve file, ignore
# ZTF21aahckft not present in light curve file, ignore
# ZTF21aahdvll not present in light curve file, ignore
# ZTF21aahdahy not present in light curve file, ignore
# ZTF21aahcibh not present in light curve file, ignore
# ZTF21aahcjgt not present in light curve file, ignore
# ZTF21aahbpgt not present in light curve file, ignore
# ZTF21aahczvq not present in light curve file, ignore
# ZTF21aahbqgt not present in light curve file, ignore
# ZTF21aahbuic not present in light curve file, ignore
# ZTF21aahcxru not present in light curve file, ignore
# ZTF21aahbhqy not present in light curve file, ignore
# ZTF21aahcijq not present in light curve file, ignore
# ZTF21aahbgnl not present in light curve file, ignore
# ZTF21aahcqns not present in light curve file, ignore
# ZTF21aahbhzb not present in light curve file, ignore
# ZTF21aahbell not present in light curve file, ignore
# ZTF21aahcibk not present in light curve file, ignore
# ZTF21aahbors not present in light curve file, ignore
# ZTF21aahertt not present in light curve file, ignore
# ZTF21aahenfk not present in light curve file, ignore
# ZTF21aahfdyn not present in light curve file, ignore
# ZTF21aahbofh not present in light curve file, ignore
# ZTF21aahaedu not present in light curve file, ignore
# ZTF21aahbfhb not present in light curve file, ignore
# ZTF21aahdkwj not present in light curve file, ignore
# ZTF21aahcikv not present in light curve file, ignore
# ZTF21aahboao not present in light curve file, ignore
# ZTF21aahcjfb not present in light curve file, ignore
# ZTF21aahbidw not present in light curve file, ignore
# ZTF21aahbgxu not present in light curve file, ignore
# ZTF21aahbppp not present in light curve file, ignore
# ZTF21aahatiz not present in light curve file, ignore
# ZTF21aahbpxj not present in light curve file, ignore
# ZTF21aahdait not present in light curve file, ignore
# ZTF21aahfbnh not present in light curve file, ignore
# ZTF21aahfdnk not present in light curve file, ignore
# ZTF21aaherhn not present in light curve file, ignore
# ZTF21aahbufg not present in light curve file, ignore
# ZTF21aahbfvc not present in light curve file, ignore
# ZTF21aahbkns not present in light curve file, ignore
# ZTF21aahbgzt not present in light curve file, ignore
# ZTF21aahbfnm not present in light curve file, ignore
# ZTF21aahchvp not present in light curve file, ignore
# ZTF21aahclbd not present in light curve file, ignore
# ZTF21aaherjp not present in light curve file, ignore
# ZTF21aahbgog not present in light curve file, ignore
# ZTF21aahcxml not present in light curve file, ignore
# ZTF21aahfeyv not present in light curve file, ignore
# ZTF21aahbyij not present in light curve file, ignore
# ZTF21aahcybq not present in light curve file, ignore
# ZTF21aahbnvj not present in light curve file, ignore
# ZTF21aahfdhz not present in light curve file, ignore
# ZTF21aahcjcx not present in light curve file, ignore
# ZTF21aahdvgp not present in light curve file, ignore
# ZTF21aagzsml not present in light curve file, ignore
# ZTF21aahcifa not present in light curve file, ignore
# ZTF21aahanrd not present in light curve file, ignore
# ZTF21aahbpuq not present in light curve file, ignore
# ZTF21aahbgnc not present in light curve file, ignore
# ZTF21aahbugi not present in light curve file, ignore
# ZTF21aahbtvy not present in light curve file, ignore
# ZTF21aahcidm not present in light curve file, ignore
# ZTF21aahcxxj not present in light curve file, ignore
# ZTF21aahcfgu not present in light curve file, ignore
# ZTF21aahczrr not present in light curve file, ignore
# ZTF21aahbnqw not present in light curve file, ignore
# ZTF21aahaung not present in light curve file, ignore
# ZTF21aahbqei not present in light curve file, ignore
# ZTF21aahbdzl not present in light curve file, ignore
# ZTF21aahcdiz not present in light curve file, ignore
# ZTF21aahboys not present in light curve file, ignore
# ZTF21aahcjpb not present in light curve file, ignore
# ZTF21aahbgqq not present in light curve file, ignore
# ZTF21aahbnlm not present in light curve file, ignore
# ZTF21aahappq not present in light curve file, ignore
# ZTF21aahdogg not present in light curve file, ignore
# ZTF21aahcjhm not present in light curve file, ignore
# ZTF21aahbgxc not present in light curve file, ignore
# ZTF21aahbzze not present in light curve file, ignore
# ZTF21aahbham not present in light curve file, ignore
# ZTF21aahcqkn not present in light curve file, ignore
# ZTF21aahczvk not present in light curve file, ignore
# ZTF21aahcjsh not present in light curve file, ignore
# ZTF21aahbuaf not present in light curve file, ignore
# ZTF21aahbnnm not present in light curve file, ignore
# ZTF21aahenug not present in light curve file, ignore
# ZTF21aahdodq not present in light curve file, ignore
# ZTF21aahaudy not present in light curve file, ignore
# ZTF21aahbhvy not present in light curve file, ignore
# ZTF21aahancq not present in light curve file, ignore
# ZTF21aaheqzd not present in light curve file, ignore
# ZTF21aahdler not present in light curve file, ignore
# ZTF21aahdoky not present in light curve file, ignore
# ZTF21aahdveh not present in light curve file, ignore
# ZTF21aahdjxn not present in light curve file, ignore
# ZTF21aahbujn not present in light curve file, ignore
# ZTF21aahcjas not present in light curve file, ignore
# ZTF21aahbhaa not present in light curve file, ignore
# ZTF21aahdalz not present in light curve file, ignore
# ZTF21aahbrkt not present in light curve file, ignore
# ZTF21aahdagf not present in light curve file, ignore
# ZTF21aahciot not present in light curve file, ignore
# ZTF21aahbdqd not present in light curve file, ignore
# ZTF21aahbdzk not present in light curve file, ignore
# ZTF21aahbife not present in light curve file, ignore
# ZTF21aahbgng not present in light curve file, ignore
# ZTF21aahbjfr not present in light curve file, ignore
# ZTF21aahboax not present in light curve file, ignore
# ZTF21aahborl not present in light curve file, ignore
# ZTF21aahdanb not present in light curve file, ignore
# ZTF21aahbrpu not present in light curve file, ignore
# ZTF21aahbhcs not present in light curve file, ignore
# ZTF21aahbocz not present in light curve file, ignore
# ZTF21aagzslw not present in light curve file, ignore
# ZTF21aahbhnm not present in light curve file, ignore
# ZTF21aahfeet not present in light curve file, ignore
# ZTF21aahbivc not present in light curve file, ignore
# ZTF21aahbicl not present in light curve file, ignore
# ZTF21aahbhbj not present in light curve file, ignore
# ZTF21aahboec not present in light curve file, ignore
# ZTF21aahczpu not present in light curve file, ignore
# ZTF21aahdajb not present in light curve file, ignore
# ZTF21aahbphx not present in light curve file, ignore
# ZTF21aahbcwd not present in light curve file, ignore
# ZTF21aahamzi not present in light curve file, ignore
# ZTF21aahbijc not present in light curve file, ignore
# ZTF21aahbgjm not present in light curve file, ignore
# ZTF21aahbxxv not present in light curve file, ignore
# ZTF21aahcjcw not present in light curve file, ignore
# ZTF21aahchuc not present in light curve file, ignore
# ZTF21aahbnyi not present in light curve file, ignore
# ZTF21aahbfgd not present in light curve file, ignore
# ZTF21aahdvkh not present in light curve file, ignore
# ZTF21aahagrt not present in light curve file, ignore
# ZTF21aahbgde not present in light curve file, ignore
# ZTF21aahbugj not present in light curve file, ignore
# ZTF21aahdlem not present in light curve file, ignore
# ZTF21aahbeer not present in light curve file, ignore
# ZTF21aahcjdi not present in light curve file, ignore
# ZTF21aahdlbx not present in light curve file, ignore
# ZTF21aahberd not present in light curve file, ignore
# ZTF21aahdlce not present in light curve file, ignore
# ZTF21aaheqsl not present in light curve file, ignore
# ZTF21aahfcmx not present in light curve file, ignore
# ZTF21aahaixj not present in light curve file, ignore
# ZTF21aahbeeu not present in light curve file, ignore
# ZTF21aahcimc not present in light curve file, ignore
# ZTF21aahdvlj not present in light curve file, ignore
# ZTF21aahfduh not present in light curve file, ignore
# ZTF21aahdxvd not present in light curve file, ignore
# ZTF21aagzsmt not present in light curve file, ignore
# ZTF21aahfebq not present in light curve file, ignore
# ZTF21aahcird not present in light curve file, ignore
# ZTF21aahbpei not present in light curve file, ignore
# ZTF21aahcimi not present in light curve file, ignore
# ZTF21aahbfnk not present in light curve file, ignore
# ZTF21aahbeqv not present in light curve file, ignore
# ZTF21aahboyp not present in light curve file, ignore
# ZTF21aahbezy not present in light curve file, ignore
# ZTF21aagzsnd not present in light curve file, ignore
# ZTF21aahbibl not present in light curve file, ignore
# ZTF21aahbeze not present in light curve file, ignore
# ZTF21aahbogg not present in light curve file, ignore
# ZTF21aahbims not present in light curve file, ignore
# ZTF21aahcihk not present in light curve file, ignore
# ZTF21aahdqwk not present in light curve file, ignore
# ZTF21aahbfve not present in light curve file, ignore
# ZTF21aahccgt not present in light curve file, ignore
# ZTF21aahbqiy not present in light curve file, ignore
# ZTF21aahcirc not present in light curve file, ignore
# ZTF21aahcxos not present in light curve file, ignore
# ZTF21aahckfs not present in light curve file, ignore
# ZTF21aahbpie not present in light curve file, ignore
# ZTF21aahbicn not present in light curve file, ignore
# ZTF21aaherjr not present in light curve file, ignore
# ZTF21aahfdyj not present in light curve file, ignore
# ZTF21aahcjbb not present in light curve file, ignore
# ZTF21aahbiix not present in light curve file, ignore
# ZTF21aahbgzj not present in light curve file, ignore
# ZTF21aahbfhc not present in light curve file, ignore
# ZTF21aahbhnv not present in light curve file, ignore
# ZTF21aahcibl not present in light curve file, ignore
# ZTF21aahbdwh not present in light curve file, ignore
# ZTF21aaherao not present in light curve file, ignore
# ZTF21aahbhny not present in light curve file, ignore
# ZTF21aahbwuo not present in light curve file, ignore
# ZTF21aahboim not present in light curve file, ignore
# ZTF21aahbqcj not present in light curve file, ignore
# ZTF21aahazxz not present in light curve file, ignore
# ZTF21aahcitk not present in light curve file, ignore
# ZTF21aahbhhe not present in light curve file, ignore
# ZTF21aahbucj not present in light curve file, ignore
# ZTF21aagzsia not present in light curve file, ignore
# ZTF21aahcggv not present in light curve file, ignore
# ZTF21aahbchz not present in light curve file, ignore
# ZTF21aahbpbm not present in light curve file, ignore
# ZTF21aahciku not present in light curve file, ignore
# ZTF21aahchjb not present in light curve file, ignore
# ZTF21aahbgdo not present in light curve file, ignore
# ZTF21aahcyey not present in light curve file, ignore
# ZTF21aahcxwe not present in light curve file, ignore
# ZTF21aahczpg not present in light curve file, ignore
# ZTF21aahbiis not present in light curve file, ignore
# ZTF21aahcjne not present in light curve file, ignore
# ZTF21aahbkax not present in light curve file, ignore
# ZTF21aahbqnm not present in light curve file, ignore
# ZTF21aahbggz not present in light curve file, ignore
# ZTF21aahcihq not present in light curve file, ignore
# ZTF21aahcjok not present in light curve file, ignore
# ZTF21aagzsjt not present in light curve file, ignore
# ZTF21aahdanc not present in light curve file, ignore
# ZTF21aahbhim not present in light curve file, ignore
# ZTF21aahbfrx not present in light curve file, ignore
# ZTF21aahbicv not present in light curve file, ignore
# ZTF21aahbfnq not present in light curve file, ignore
# ZTF21aahcjez not present in light curve file, ignore
# ZTF21aahbfdw not present in light curve file, ignore
# ZTF21aahbotm not present in light curve file, ignore
# ZTF21aahbgti not present in light curve file, ignore
# ZTF21aahbdxh not present in light curve file, ignore
# ZTF21aahbqmh not present in light curve file, ignore
# ZTF21aahepho not present in light curve file, ignore
# ZTF21aahczbq not present in light curve file, ignore
# ZTF21aahcjny not present in light curve file, ignore
# ZTF21aahcxfh not present in light curve file, ignore
# ZTF21aahcxuk not present in light curve file, ignore
# ZTF21aahbvrj not present in light curve file, ignore
# ZTF21aahcihp not present in light curve file, ignore
# ZTF21aahcrqk not present in light curve file, ignore
# ZTF21aahdveo not present in light curve file, ignore
# ZTF21aahbire not present in light curve file, ignore
# ZTF21aahebkw not present in light curve file, ignore
# ZTF21aaheqss not present in light curve file, ignore
# ZTF21aahbxxq not present in light curve file, ignore
# ZTF21aahckdg not present in light curve file, ignore
# ZTF21aahccqv not present in light curve file, ignore
# ZTF21aahbifh not present in light curve file, ignore
# ZTF21aahcjlp not present in light curve file, ignore
# ZTF21aahadpf not present in light curve file, ignore
# ZTF21aahcjdr not present in light curve file, ignore
# ZTF21aahepet not present in light curve file, ignore
# ZTF21aahdlqw not present in light curve file, ignore
# ZTF21aahaqoq not present in light curve file, ignore
# ZTF21aahbhri not present in light curve file, ignore
# ZTF21aahbifz not present in light curve file, ignore
# ZTF21aahbwbi not present in light curve file, ignore
# ZTF21aahbion not present in light curve file, ignore
# ZTF21aahbhnn not present in light curve file, ignore
# ZTF21aahcjln not present in light curve file, ignore
# ZTF21aahcjnk not present in light curve file, ignore
# ZTF21aahbtyj not present in light curve file, ignore
# ZTF21aaheogc not present in light curve file, ignore
# ZTF21aahbhyl not present in light curve file, ignore
# ZTF21aahcict not present in light curve file, ignore
# ZTF21aahbevd not present in light curve file, ignore
# ZTF21aahciwn not present in light curve file, ignore
# ZTF21aahdvik not present in light curve file, ignore
# ZTF21aahbdwi not present in light curve file, ignore
# ZTF21aahbpmf not present in light curve file, ignore
# ZTF21aahbnlx not present in light curve file, ignore
# ZTF21aahbdzg not present in light curve file, ignore
# ZTF21aahbhlf not present in light curve file, ignore
# ZTF21aahbnsf not present in light curve file, ignore
# ZTF21aahcxzk not present in light curve file, ignore
# ZTF21aahbtts not present in light curve file, ignore
# ZTF21aahchxe not present in light curve file, ignore
# ZTF21aahcjfd not present in light curve file, ignore
# ZTF21aagzsnq not present in light curve file, ignore
# ZTF21aahbhlm not present in light curve file, ignore
# ZTF21aahczsh not present in light curve file, ignore
# ZTF21aahbppn not present in light curve file, ignore
# ZTF21aahcxzz not present in light curve file, ignore
# ZTF21aahdveq not present in light curve file, ignore
# ZTF21aahauym not present in light curve file, ignore
# ZTF21aahcipm not present in light curve file, ignore
# ZTF21aahdvek not present in light curve file, ignore
# ZTF21aahbflj not present in light curve file, ignore
# ZTF21aahbflb not present in light curve file, ignore
# ZTF21aahcxlh not present in light curve file, ignore
# ZTF21aahbgwa not present in light curve file, ignore
# ZTF21aahcxmz not present in light curve file, ignore
# ZTF21aahbiys not present in light curve file, ignore
# ZTF21aahcidc not present in light curve file, ignore
# ZTF21aahcybp not present in light curve file, ignore
# ZTF21aahbqcm not present in light curve file, ignore
# ZTF21aagzskj not present in light curve file, ignore
# ZTF21aahbqrh not present in light curve file, ignore
# ZTF21aahbeyy not present in light curve file, ignore
# ZTF21aahdvir not present in light curve file, ignore
# ZTF21aahbhmu not present in light curve file, ignore
# ZTF21aahctwg not present in light curve file, ignore
# ZTF21aahfdyo not present in light curve file, ignore
# ZTF21aahbpah not present in light curve file, ignore
# ZTF21aahbhzl not present in light curve file, ignore
# ZTF21aahbwui not present in light curve file, ignore
# ZTF21aahbgxv not present in light curve file, ignore
# ZTF21aahephv not present in light curve file, ignore
# ...
# ZTF21aahbqbu not present in light curve file, ignore
# ZTF21aahciws not present in light curve file, ignore
# ZTF21aahfdex not present in light curve file, ignore
# ZTF21aahbpta not present in light curve file, ignore
# ZTF21aahdldx not present in light curve file, ignore
# ZTF21aahbokg not present in light curve file, ignore
# ZTF21aahcyjp not present in light curve file, ignore
# ZTF21aahbpqm not present in light curve file, ignore
# ZTF21aahdlbw not present in light curve file, ignore
# ZTF21aahcxur not present in light curve file, ignore
# ZTF21aahbfld not present in light curve file, ignore
# ZTF21aahbeqz not present in light curve file, ignore
# ZTF21aahbufj not present in light curve file, ignore
# ZTF21aahfcuz not present in light curve file, ignore
# ZTF21aahbpsd not present in light curve file, ignore
# ZTF21aahbdzh not present in light curve file, ignore
# ZTF21aahbfnl not present in light curve file, ignore
# ZTF21aahcipa not present in light curve file, ignore
# ZTF21aahfebr not present in light curve file, ignore
# ZTF21aahbhzd not present in light curve file, ignore
# ZTF21aahcjin not present in light curve file, ignore
# ZTF21aahbgfc not present in light curve file, ignore
# ZTF21aahcukt not present in light curve file, ignore
# ZTF21aahboin not present in light curve file, ignore
# ZTF21aahbhhj not present in light curve file, ignore
# ZTF21aagzsmu not present in light curve file, ignore
# ZTF21aahfcxq not present in light curve file, ignore
# ZTF21aahbjjd not present in light curve file, ignore
# ZTF21aahbdhu not present in light curve file, ignore
# ZTF21aahbtsr not present in light curve file, ignore
# ZTF21aahbuac not present in light curve file, ignore
# ZTF21aahcxor not present in light curve file, ignore
# ZTF21aahbnte not present in light curve file, ignore
# ZTF21aahbpid not present in light curve file, ignore
# ZTF21aahbibr not present in light curve file, ignore
# ZTF21aahbegm not present in light curve file, ignore
# ZTF21aahbhei not present in light curve file, ignore
# ZTF21aahchbj not present in light curve file, ignore
# ZTF21aahbida not present in light curve file, ignore
# ZTF21aagzssb not present in light curve file, ignore
# ZTF21aahbfim not present in light curve file, ignore
# ZTF21aahczpv not present in light curve file, ignore
# ZTF21aahcfwm not present in light curve file, ignore
# ZTF21aahbhgk not present in light curve file, ignore
# ZTF21aahbwln not present in light curve file, ignore
# ZTF21aahbnik not present in light curve file, ignore
# ZTF21aahbhad not present in light curve file, ignore
# ZTF21aahepkq not present in light curve file, ignore
# ZTF21aahbhdh not present in light curve file, ignore
# ZTF21aahdvfw not present in light curve file, ignore
# ZTF21aahccpp not present in light curve file, ignore
# ZTF21aahckkg not present in light curve file, ignore
# ZTF21aahcjwk not present in light curve file, ignore
# ZTF21aahcibo not present in light curve file, ignore
# ZTF21aahcilp not present in light curve file, ignore
# ZTF21aahcgux not present in light curve file, ignore
# ZTF21aahdacd not present in light curve file, ignore
# ZTF21aahbpnh not present in light curve file, ignore
# ZTF21aaheqhj not present in light curve file, ignore
# ZTF21aagzsjj not present in light curve file, ignore
# ZTF21aahchzr not present in light curve file, ignore
# ZTF21aahdabv not present in light curve file, ignore
# ZTF21aahajqb not present in light curve file, ignore
# ZTF21aagzsnk not present in light curve file, ignore
# ZTF21aahbglq not present in light curve file, ignore
# ZTF21aahemzg not present in light curve file, ignore
# ZTF21aahbzqq not present in light curve file, ignore
# ZTF21aahbnko not present in light curve file, ignore
# ZTF21aahborm not present in light curve file, ignore
# ZTF21aahcifg not present in light curve file, ignore
# ZTF21aahcxft not present in light curve file, ignore
# ZTF21aahbiep not present in light curve file, ignore
# ZTF21aahbhgd not present in light curve file, ignore
# ZTF21aahcicy not present in light curve file, ignore
# ZTF21aahbdwp not present in light curve file, ignore
# ZTF21aahcijc not present in light curve file, ignore
# ZTF21aahcihi not present in light curve file, ignore
# ZTF21aahfcvd not present in light curve file, ignore
# ZTF21aahenwd not present in light curve file, ignore
# ZTF21aahdamb not present in light curve file, ignore
# ZTF21aahbiip not present in light curve file, ignore
# ZTF21aahckqj not present in light curve file, ignore
# ZTF21aahbpgv not present in light curve file, ignore
# ZTF21aahbqdo not present in light curve file, ignore
# ZTF21aahbeeq not present in light curve file, ignore
# ZTF21aahbnwn not present in light curve file, ignore
# ZTF21aahbnvp not present in light curve file, ignore
# ZTF21aahernh not present in light curve file, ignore
# ZTF21aahdaqq not present in light curve file, ignore
# ZTF21aahbgoj not present in light curve file, ignore
# ZTF21aahdvex not present in light curve file, ignore
# ZTF21aahcjdt not present in light curve file, ignore
# ZTF21aahbxol not present in light curve file, ignore
# ZTF21aahduuk not present in light curve file, ignore
# ZTF21aahbeew not present in light curve file, ignore
# ZTF21aahcipn not present in light curve file, ignore
# ZTF21aahcyfg not present in light curve file, ignore
# ZTF21aahcikb not present in light curve file, ignore
# ZTF21aahbgku not present in light curve file, ignore
# ZTF21aahbfaa not present in light curve file, ignore
# ZTF21aahbeln not present in light curve file, ignore
# ZTF21aahbgzm not present in light curve file, ignore
# ZTF21aahewiy not present in light curve file, ignore
# ZTF21aahbort not present in light curve file, ignore
# ZTF21aahbpag not present in light curve file, ignore
# ZTF21aaheodb not present in light curve file, ignore
# ZTF21aahfcvb not present in light curve file, ignore
# ZTF21aahensm not present in light curve file, ignore
# ZTF21aahbiau not present in light curve file, ignore
# ZTF21aagzsns not present in light curve file, ignore
# ZTF21aahcymq not present in light curve file, ignore
# ZTF21aahbuga not present in light curve file, ignore
# ZTF21aahbhax not present in light curve file, ignore
# ZTF21aahcipw not present in light curve file, ignore
# ZTF21aahepfs not present in light curve file, ignore
# ZTF21aahbnny not present in light curve file, ignore
# ZTF21aahbxxp not present in light curve file, ignore
# ZTF21aahbheh not present in light curve file, ignore
# ZTF21aahbhqg not present in light curve file, ignore
# ZTF21aahbrgq not present in light curve file, ignore
# ZTF21aahbhls not present in light curve file, ignore
# ZTF21aahbgzq not present in light curve file, ignore
# ZTF21aahbqon not present in light curve file, ignore
# ZTF21aahbfgf not present in light curve file, ignore
# ZTF21aahbrei not present in light curve file, ignore
# ZTF21aahbhmw not present in light curve file, ignore
# ZTF21aahdlrb not present in light curve file, ignore
# ZTF21aahbpxn not present in light curve file, ignore
# ZTF21aahbhrv not present in light curve file, ignore
# ZTF21aahcixf not present in light curve file, ignore
# ZTF21aahbfbd not present in light curve file, ignore
# ZTF21aahaqau not present in light curve file, ignore
# ZTF21aahcylv not present in light curve file, ignore
# ZTF21aahffkz not present in light curve file, ignore
# ZTF21aaheplm not present in light curve file, ignore
# ZTF21aahduul not present in light curve file, ignore
# ZTF21aahbnin not present in light curve file, ignore
# ZTF21aahczyd not present in light curve file, ignore
# ZTF21aahbnvn not present in light curve file, ignore
# ZTF21aaheork not present in light curve file, ignore
# ZTF21aahapdu not present in light curve file, ignore
# ZTF21aahadpj not present in light curve file, ignore
# ZTF21aahbfpo not present in light curve file, ignore
# ZTF21aagzsno not present in light curve file, ignore
# ZTF21aahcwre not present in light curve file, ignore
# ZTF21aahbqov not present in light curve file, ignore
# ZTF21aahbfvh not present in light curve file, ignore
# ZTF21aahemzf not present in light curve file, ignore
# ZTF21aahbeng not present in light curve file, ignore
# ZTF21aahcjcy not present in light curve file, ignore
# ZTF21aahbnku not present in light curve file, ignore
# ZTF21aahbqew not present in light curve file, ignore
# ZTF21aahbfdv not present in light curve file, ignore
# ZTF21aahbxiv not present in light curve file, ignore
# ZTF21aahfdid not present in light curve file, ignore
# ZTF21aahcjeu not present in light curve file, ignore
# ZTF21aahdldn not present in light curve file, ignore
# ZTF21aahcxlo not present in light curve file, ignore
# ZTF21aaherse not present in light curve file, ignore
# ZTF21aahbdzm not present in light curve file, ignore
# ZTF21aahbhat not present in light curve file, ignore
# ZTF21aahcymu not present in light curve file, ignore
# ZTF21aahdlby not present in light curve file, ignore
# ZTF21aahcyrr not present in light curve file, ignore
# ZTF21aaheqza not present in light curve file, ignore
# ZTF21aahepfz not present in light curve file, ignore
# ZTF21aahbdpx not present in light curve file, ignore
# ZTF21aahcgkr not present in light curve file, ignore
# ZTF21aahcbfe not present in light curve file, ignore
# ZTF21aahboyq not present in light curve file, ignore
# ZTF21aahchyf not present in light curve file, ignore
# ZTF21aahcijs not present in light curve file, ignore
# ZTF21aahchqt not present in light curve file, ignore
# ZTF21aahcill not present in light curve file, ignore
# ZTF21aahcyex not present in light curve file, ignore
# ZTF21aahbhrl not present in light curve file, ignore
# ZTF21aahfbpk not present in light curve file, ignore
# ZTF21aagzsop not present in light curve file, ignore
# ZTF21aahbffd not present in light curve file, ignore
# ZTF21aahckfy not present in light curve file, ignore
# ZTF21aahdvew not present in light curve file, ignore
# ZTF21aahczzy not present in light curve file, ignore
# ZTF21aahdbtu not present in light curve file, ignore
# ZTF21aahbojg not present in light curve file, ignore
# ZTF21aahbmrj not present in light curve file, ignore
# ZTF21aahcgia not present in light curve file, ignore
# ZTF21aahcixc not present in light curve file, ignore
# ZTF21aahbgje not present in light curve file, ignore
# ZTF21aahbnlz not present in light curve file, ignore
# ZTF21aahdvfi not present in light curve file, ignore
# ZTF21aahcyig not present in light curve file, ignore
# ZTF21aahczvz not present in light curve file, ignore
# ZTF21aahdagk not present in light curve file, ignore
# ZTF21aahbpos not present in light curve file, ignore
# ZTF21aahcfer not present in light curve file, ignore
# ZTF21aahbgsn not present in light curve file, ignore
# ZTF21aahbgeq not present in light curve file, ignore
# ZTF21aahbhrg not present in light curve file, ignore
# ZTF21aahbffe not present in light curve file, ignore
# ZTF21aahbudv not present in light curve file, ignore
# ZTF21aahbqgk not present in light curve file, ignore
# ZTF21aahchny not present in light curve file, ignore
# ZTF21aahbdwd not present in light curve file, ignore
# ZTF21aahbtwf not present in light curve file, ignore
# ZTF21aahchaq not present in light curve file, ignore
# ZTF21aahfdgi not present in light curve file, ignore
# ZTF21aahbnvo not present in light curve file, ignore
# ZTF21aahcioa not present in light curve file, ignore
# ZTF21aahbfzv not present in light curve file, ignore
# ZTF21aahcyim not present in light curve file, ignore
# ZTF21aahbvrl not present in light curve file, ignore
# ZTF21aahbhgx not present in light curve file, ignore
# ZTF21aahbfhl not present in light curve file, ignore
# ZTF21aahbimq not present in light curve file, ignore
# ZTF21aahbnmu not present in light curve file, ignore
# ZTF21aagzsmc not present in light curve file, ignore
# ZTF21aahenfl not present in light curve file, ignore
# ZTF21aahcimk not present in light curve file, ignore
# ZTF21aahbpai not present in light curve file, ignore
# ZTF21aahdapy not present in light curve file, ignore
# ZTF21aahckgt not present in light curve file, ignore
# ZTF21aahbfff not present in light curve file, ignore
# ZTF21aahbqde not present in light curve file, ignore
# ZTF21aahbugb not present in light curve file, ignore
# ZTF21aahffjs not present in light curve file, ignore
# ZTF21aahbeqw not present in light curve file, ignore
# ZTF21aahbuaq not present in light curve file, ignore
# ZTF21aahcjjh not present in light curve file, ignore
# ZTF21aahcjng not present in light curve file, ignore
# ZTF21aahfftj not present in light curve file, ignore
# ZTF21aahbhfn not present in light curve file, ignore
# ZTF21aahbhgc not present in light curve file, ignore
# ZTF21aahberf not present in light curve file, ignore
# ZTF21aahdriy not present in light curve file, ignore
# ZTF21aahbnqi not present in light curve file, ignore
# ZTF21aahdjxk not present in light curve file, ignore
# ZTF21aahbnrq not present in light curve file, ignore
# ZTF21aahcidl not present in light curve file, ignore
# ZTF21aahczvu not present in light curve file, ignore
# ZTF21aahcxfn not present in light curve file, ignore
# ZTF21aagzsvq not present in light curve file, ignore
# ZTF21aahdvhc not present in light curve file, ignore
# ZTF21aahciwc not present in light curve file, ignore
# ZTF21aahbnlk not present in light curve file, ignore
# ZTF21aahczyy not present in light curve file, ignore
# ZTF21aahcggy not present in light curve file, ignore
# ZTF21aahemzi not present in light curve file, ignore
# ZTF21aahdlqs not present in light curve file, ignore
# ZTF21aahbftg not present in light curve file, ignore
# ZTF21aaheplh not present in light curve file, ignore
# ZTF21aahbpse not present in light curve file, ignore
# ZTF21aahcfzb not present in light curve file, ignore
# ZTF21aahbfkp not present in light curve file, ignore
# ZTF21aahcihg not present in light curve file, ignore
# ZTF21aahbfne not present in light curve file, ignore
# ZTF21aahbieb not present in light curve file, ignore
# ZTF21aahctni not present in light curve file, ignore
# ZTF21aahdqwi not present in light curve file, ignore
# ZTF21aahbhob not present in light curve file, ignore
# ZTF21aahcido not present in light curve file, ignore
# ZTF21aahdogc not present in light curve file, ignore
# ZTF21aahbfkn not present in light curve file, ignore
# ZTF21aahcyln not present in light curve file, ignore
# ZTF21aahbezd not present in light curve file, ignore
# ZTF21aaheqhe not present in light curve file, ignore
# ZTF21aahciie not present in light curve file, ignore
# ZTF21aahddvi not present in light curve file, ignore
# ZTF21aahcxms not present in light curve file, ignore
# ZTF21aahbotn not present in light curve file, ignore
# ZTF21aahcwrd not present in light curve file, ignore
# ZTF21aahbpdm not present in light curve file, ignore
# ZTF21aahbeih not present in light curve file, ignore
# ZTF21aahbqbi not present in light curve file, ignore
# ZTF21aahbhbm not present in light curve file, ignore
# ZTF21aahbnpi not present in light curve file, ignore
# ZTF21aahbibz not present in light curve file, ignore
# ZTF21aahbhjk not present in light curve file, ignore
# ZTF21aahfdyl not present in light curve file, ignore
# ZTF21aahcjtn not present in light curve file, ignore
# ZTF21aahbdwe not present in light curve file, ignore
# ZTF21aahcxlz not present in light curve file, ignore
# ZTF21aahbeum not present in light curve file, ignore
# ZTF21aahbohr not present in light curve file, ignore
# ZTF21aahdnma not present in light curve file, ignore
# ZTF21aahcibe not present in light curve file, ignore
# ZTF21aahbplq not present in light curve file, ignore
# ZTF21aahbnzc not present in light curve file, ignore
# ZTF21aahcwuq not present in light curve file, ignore
# ZTF21aahboxm not present in light curve file, ignore
# ZTF21aahciwv not present in light curve file, ignore
# ZTF21aahfcii not present in light curve file, ignore
# ZTF21aagzslo not present in light curve file, ignore
# ZTF21aahbhzm not present in light curve file, ignore
# ZTF21aahbgtn not present in light curve file, ignore
# ZTF21aahcxzw not present in light curve file, ignore
# ZTF21aahbggy not present in light curve file, ignore
# ZTF21aahbqem not present in light curve file, ignore
# ZTF21aahbzlf not present in light curve file, ignore
# ZTF21aagzskp not present in light curve file, ignore
# ZTF21aahcxuq not present in light curve file, ignore
# ZTF21aahbgkg not present in light curve file, ignore
# Number of sources to vet: 336

# %%
len(names_selected)
# Out:
# 336

# %% [markdown]
# Plot the light curves and complete the candidate vetting on [Fritz](https://fritz.science). which one of the selected transients is most likely a genuine extragalactic fast transient?

# %%
plot_lc(names_selected[5])

# %%
names_selected[5]
# Out:
# 'ZTF21aahcchj'

# %%
plot_lc(names_selected[28])

# %% [markdown]
# # Epilogue
#
# Epilogue to be read in the `fast_transients_solutions.ipynb` notebook!
